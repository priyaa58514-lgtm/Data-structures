# %%
class Node:
    def __init__ (self,data):
        self.data=data
        self.left=none
        self.right=none
    def indorder (root):
        if root:
            inorder(root.left)
            print(rot.data,end=" ")
            inorder(root.right)
    def preorder(root):
        if root:
            print(root.data,end=" ")
            preorder(root.left)
            preorder(root.right)
    def postorder(root):
        if root:
            postoredr(root.left)
            postorder(root.right)
            print(root.data,end=" ")

            root=node(1)
            root.left=node(2)
            root.right=node(3)
            root.left.left=node(3)
            root.left.right=node()
